# %% [markdown]
# # Control System Engineering

# %% [markdown]
# ### Overview of the Course:
# * Modelling of the System - represents by equations and apply representations in graphical form.
# * Obtain the overall Transform function of canonical form of a feedback of the system.
# * Cyber - What is the implication of the word Cyber in what's happening in our world.
#
# TIME $ \rightarrow $ SIGNAL
#
# FREQUENCY
#
# * LAPLACE - adjective, transform, mathematician

# %% [markdown]
# $ s = \sigma + j\omega $
#
# $ \omega = 2\pi f ; f = frequency \ domain $
#
#
# complex = real part, imaginary part, $ \omega = 2\pi f ; f = frequency \ domain $
#
#
# s = complex frequency variable
#
# DE $ \leftrightarrow $ algebra
#
# TIME DOMAIN ( $ c(t) = h(t)*r(t) $ ) - convolution
#
# FREQUENCY DOMAIN ( $ C(s) = R(s)H(s) $ ) - transfer function

# %% [markdown]
# INDUCTOR:
#
# $ V = IR $ - represents the relationship btween the input current and output voltage in a resistor
#
# $ V = L \frac{di}{dt} $ - Faraday's Law
#
# $ \int tdt = 0 $
#
# $ V = \Phi = \frac{d\theta}{dt} $ - direct derivation

# %% [markdown]
# R = Lineart Device , R is in the slope of resistance.

# %% [markdown]
# CAPACITOR: Fundamental quantity of electricity - Charge (Coloumb)
#
# $ i = \frac{1}{L} \int vdt $
#
# $ i = \frac{dq}{dt} \leftrightarrow q\int{dt} $
#
# $ C = \frac{q}{v} $
#
# $ q = Cr $
#
# $ \frac{dq}{dt} = C \frac{dr}{dt} $

# %% [markdown]
# #### LAPLACE TABLE
# ![laplace.PNG](attachment:laplace.PNG)

# %% [markdown]
# ### CSE (02 - 16 - 2021)
# * Model - representation of physical system
# * Mathematical Model
# * Model - abstraction of the actual system, abstracting thye mechanical characteristics in simple parameter
# * Equation must really pertain to system
# * Differential Equations - all system are dynamic (changes with time), time is the independent variable
# * Mechanical components: Motion ($ F = ma$), Force, By meand of coordinate system
# * Electrical component: can be studied by 3 parameters (Resistance, Inductance, and Capacitance (R, L, C))
# $$ V = iR \ (RESISTANCE)$$
# $$ V_L = L\frac{di}{dt} \ (INDUCTANCE) $$
# $$ V_C = \frac{1}{C}\int{idt} \ (CAPACITANCE)$$
# * R, L, C - model most physical system

# %% [markdown]
# Newton's Second Law of Motion $\rightarrow$ $ F = ma = \frac{md^{2}x}{dt} $
#
# $ F = B\frac{dx}{dt} = dx (velocity) = \frac{dt}{dv} $ $\rightarrow$ resistance to motion, Empirical formula (B - represents "damping", resistance)(pagnagdrive ng mabilis, ung hangin ung pipigil sa iyo, may resistance - hangin)
#
# $ F = kx \rightarrow \ elongation $ $\rightarrow$ Hooke's Model

# %% [markdown]
# $ P = i^{2}R $ $\rightarrow$ R - "Resistor to limit the current" (kung wala, walang power)

# %% [markdown]
# Ohm's Law:
#
# $ V = IR $ $\rightarrow$ (dc system - constant)
#
# $ v = iR $ $\rightarrow$ i,v(instantaneous - vary in time)(ac system)
#
# Slope ng time $\rightarrow$ $ \frac{V}{R} = I $

# %% [markdown]
# ###### REMEMBER: Does a curve have a slope? (NO)
#
# $ R = \frac{dv}{di} $ $\rightarrow$ slope of the tangent to the curve.

# %% [markdown]
# Hertz - german word for Heart
#
# ###### REMEMBER: We can only apply Ohm's law if theres a current.....
#
# Frequency $\rightarrow$ $ \frac{Hertz}{cylce/seconds} $
#
# $ i = Gv $ $\rightarrow$ Conductance (Resistor-Conductor)

# %% [markdown]
# * Inductor - Device
# * Inductance -  characteristics, giving a value (L)
# * Electromagnetic
# * Faraday's law $\rightarrow$ $ \oint_{c} \vec{E} * \vec{dl} = -\frac{\delta}{\delta{t}}\int{\vec{B}*\vec{ds}} $
# * $ \Phi $ $\rightarrow$ Magnetic Flux
# * Volts $\rightarrow$ $ \nu = \frac{d\Phi}{dt} $ $\rightarrow$ Webber $\rightarrow$ Simplified Ohm's Law $\rightarrow$ Motor + Generator
# * $ \Phi $ $\rightarrow$ nagbabago in time (meaning may voltage)
# * $ 1 W_{b} $ $\rightarrow$ $10^{8} Maxwell = 10^{8} lines $

# %% [markdown]
# "Electro-Mechanical Machines"
#
# * $ v = L\frac{di}{dt} $
# * Inductance: $ L = \frac{T}{I} $ $\rightarrow$ nagdedevelop ng high voltage, may ignition coil
# * L $\rightarrow$ slope ng $\Phi$ and Current, slope of straight line, constant (approximation)
#
# ###### REMEMBER: Is an Inductor a linear device? (YES)
#
# * $ V = L \frac{di}{dt} $ ; $ \frac{di}{dt} $ $\rightarrow$ the current cannot change instataneously in an inductor, dt cannot be zero, this whole thing will be infinite ($\infty$)
# * In an inductor current not changing instantaneously
# * To response Faraday's Law, generated emf if flux is change in time
# * Lumiliit ang slope, lumiliit ang inductance
# * constant ng current, Derivative of constant is "0"
# * Universe was not expanding

# %% [markdown]
# CAPACITOR $\rightarrow$ device that store charges
# * cathode and anode (electrolytic)
# * charges with time  (Coloumb)
# * Q $\rightarrow$ dc
# * q $\rightarrow$ ac
# * transient $\rightarrow$ transition from one steady phase to one steady phase
# * q $\rightarrow$ how to store charges, using battery.
# * $ q = cv $ $\rightarrow$ constant of proportionality
# * $ c = \frac{q}{v} $ $\rightarrow$ amouht of change per unit voltage
# * c $\rightarrow$ the slope of $\frac{q}{v}$ curve...
# * $ i = c\frac{dv}{dt} \leftrightarrow v = \frac{1}{c}\int{idt} $
# * Lahat ng bagay ay hindi 'constant'
# * $ i = \frac{di}{dt} $
# * $ \frac{d^{2}v}{dt^{2}} \leftrightarrow i = c\frac{d^{x}v}{dt^{x}} $ $\leftrightarrow$ fractional derivative

# %% [markdown]
# ### UNDER DAMPED SECOD ORDER SYSTEM
# LINK: [UNDER DAMPED SECOD ORDER SYSTEM](https://drive.google.com/file/d/1WBMM2oFSzik6_BPmP-kUnpC7vWvZ2ueU/view?usp=sharing)

# %% [markdown]
# This repo contains an introduction to [Jupyter](https://jupyter.org) and [IPython](https://ipython.org).
#
# Outline of some basics:
#
# * [Notebook Basics](../examples/Notebook/Notebook%20Basics.ipynb)
# * [IPython - beyond plain python](../examples/IPython%20Kernel/Beyond%20Plain%20Python.ipynb)
# * [Markdown Cells](../examples/Notebook/Working%20With%20Markdown%20Cells.ipynb)
# * [Rich Display System](../examples/IPython%20Kernel/Rich%20Output.ipynb)
# * [Custom Display logic](../examples/IPython%20Kernel/Custom%20Display%20Logic.ipynb)
# * [Running a Secure Public Notebook Server](../examples/Notebook/Running%20the%20Notebook%20Server.ipynb#Securing-the-notebook-server)
# * [How Jupyter works](../examples/Notebook/Multiple%20Languages%2C%20Frontends.ipynb) to run code in different languages.
